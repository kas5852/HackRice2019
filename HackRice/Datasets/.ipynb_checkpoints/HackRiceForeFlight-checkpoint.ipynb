# %%
import pandas as pd 
import numpy as np 
from scipy import stats
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
import xgboost as xgb
from xgboost import XGBClassifier 
from xgboost import XGBRegressor
from xgboost import plot_importance
import matplotlib.pylab as plt
from matplotlib import pyplot
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_dataset = pd.read_csv("HackRiceForeFlightData_Train.csv")

# %%
test_dataset = pd.read_csv("HackRiceForeFlightData_Test.csv")

# %%
train_dataset.head()
# Out:
#       user_id airport  number_of_flights airport_type  number_fbos  \
# 0  user_31441    KSAT                  6      AIRPORT            6
# 1  user_31441    KROW                  3      AIRPORT            2
# 2  user_31441    KMAF                  2      AIRPORT            1
# 3  user_31441    KCRP                  1      AIRPORT            0
# 4  user_31441    KLBB                  1      AIRPORT            0
#
#    number_restaurants  number_hotels  number_maintenance  \
# 0                  15             10                   9
# 1                  15             10                   1
# 2                  12              8                   1
# 3                  15             13                   1
# 4                  16             10                   3
#
#    number_flight_schools  number_flying_clubs  \
# 0                      7                    0
# 1                      1                    0
# 2                      1                    0
# ...

# %%
test_dataset.head()
# Out:
#       user_id airport  number_of_flights airport_type  number_fbos  \
# 0   user_9603    KSBA                  2      AIRPORT            2
# 1   user_9603    KCRQ                  2      AIRPORT            8
# 2   user_9603    KPRB                  2      AIRPORT            1
# 3   user_9603    KIZA                  1      AIRPORT            0
# 4  user_12522    KJYO                  3      AIRPORT            4
#
#    number_restaurants  number_hotels  number_maintenance  \
# 0                  15             10                   2
# 1                  11             10                   7
# 2                  24             14                   2
# 3                  15             12                   3
# 4                  16             11                   2
#
#    number_flight_schools  number_flying_clubs                     name  \
# 0                      8                    1  Santa Barbara Municipal
# 1                     13                    2       Mc Clellan-Palomar
# ...

# %%
feature_cols = ['number_fbos','number_of_flights', 'number_restaurants', 'number_hotels', 'number_maintenance', 'number_flight_schools','number_flying_clubs', 'latitude', 'longitude']
target = 'airport'
ID_col = 'user_id'
train_features_X = train_dataset[feature_cols]
train_target_Y = train_dataset[target]
test_feature_X = test_dataset[feature_cols]
test_target_Y = test_dataset[target]
test_Id = test_dataset[ID_col]
predictors = [x for x in train_features_X.columns if x not in [target,ID_col]]
mlb = MultiLabelBinarizer()

# %%
unique_airports = test_dataset['airport'].nunique()
print(unique_airports)
# Out:
# 655

# %%
model = XGBClassifier(
    nthread=8,
    objective='multi:softmax',
    num_class='655'
)
#y = mlb.fit_transform(test_dataset[target])
y= test_dataset[target]
model.fit(test_dataset[predictors], y,eval_metric='auc')
print("Model Fitted")
print("Beginning K-Fold")
kfold = KFold(n_splits=3, random_state=42)
results = cross_val_score(model, test_feature_X, test_target_Y, cv=kfold, scoring='roc_auc')
print(results)
print(results.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-4b0c2a3bfeff> in <module>
#       5 )
#       6 y = mlb.fit_transform(test_dataset[target])
# ----> 7 model.fit(test_dataset[predictors], y,eval_metric='auc')
#       8 print("Model Fitted")
#       9 print("Beginning K-Fold")
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     679                 xgb_options.update({"eval_metric": eval_metric})
#     680
# --> 681         self._le = XGBLabelEncoder().fit(y)
#     682         training_labels = self._le.transform(y)
#     683
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit(self, y)
#     217         self : returns an instance of self.
#     218         """
# ...
